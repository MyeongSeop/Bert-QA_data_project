# %%
# !nvidia-smi
# Out:
# Tue Feb 16 05:08:15 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools

# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null

# !apt-get update -qq 2>&1 > /dev/null

# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth

auth.authenticate_user()

from oauth2client.client import GoogleCredentials

creds = GoogleCredentials.get_application_default()

import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL

vcode = getpass.getpass()

# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 146425 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.24-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.24-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.24-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# ...

# %%
# !mkdir -p Gdrive
# !google-drive-ocamlfuse Gdrive

# %%
import tensorflow as tf

print(tf.__version__)

# !pip uninstall tensorflow==2.2.0

# !pip install tensorflow==1.15.0

# !pip install bert-tensorflow
# Out:
# 2.4.1
# Uninstalling tensorflow-2.4.1:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.4.1.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.4.1
# ...
#      |████████████████████████████████| 412.3MB 43kB/s
# ...
#      |████████████████████████████████| 51kB 7.8MB/s
# ...
#      |████████████████████████████████| 512kB 60.6MB/s
# ...
#      |████████████████████████████████| 3.8MB 44.7MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=43b609eced18c606f095f1f16360f8c98b06e2db0961e5551b11b66d66c4861f
# ...

# %%
# !python Gdrive/hackathon_2-2/src/text_to_json.py Gdrive/hackathon_2-2/data/dev/dev_input.txt Gdrive/hackathon_2-2/data/dev/dev.json
# !python Gdrive/hackathon_2-2/src/json_remove_ABC_test.py Gdrive/hackathon_2-2/data/dev/dev.json Gdrive/hackathon_2-2/data/dev/convert_dev.json 1
# !python Gdrive/hackathon_2-2/src/text_to_json.py Gdrive/hackathon_2-2/data/test/test_input.txt Gdrive/hackathon_2-2/data/test/test.json
# !python Gdrive/hackathon_2-2/src/json_remove_ABC_test.py Gdrive/hackathon_2-2/data/test/test.json Gdrive/hackathon_2-2/data/test/convert_test.json 1
# Out:
# input file path : Gdrive/hackathon_2-2/data/dev/dev_input.txt
# output json file path : Gdrive/hackathon_2-2/data/dev/dev.json
# origin json file path : Gdrive/hackathon_2-2/data/dev/dev.json
# convert json file(remove A,B,C) path : Gdrive/hackathon_2-2/data/dev/convert_dev.json
# make output file size Gdrive/hackathon_2-2/data/dev/convert_dev.json times
# input file path : Gdrive/hackathon_2-2/data/test/test_input.txt
# output json file path : Gdrive/hackathon_2-2/data/test/test.json
# origin json file path : Gdrive/hackathon_2-2/data/test/test.json
# convert json file(remove A,B,C) path : Gdrive/hackathon_2-2/data/test/convert_test.json
# make output file size Gdrive/hackathon_2-2/data/test/convert_test.json times

# %%
# !python Gdrive/hackathon_2-2/src/json_remove_ABC.py Gdrive/hackathon_2-2/data/train/MedQuAD_v1.0_train.json Gdrive/hackathon_2-2/data/train/train.json 5
# Out:
# origin json file path : Gdrive/hackathon_2-2/data/train/MedQuAD_v1.0_train.json
# convert json file(remove A,B,C) path : Gdrive/hackathon_2-2/data/train/train.json
# make output file size Gdrive/hackathon_2-2/data/train/train.json times

# %%
# !python Gdrive/hackathon_2-2/src/run_squad.py \
--vocab_file=Gdrive/hackathon_2-2/src/pretrained/vocab.txt \
--bert_config_file=Gdrive/hackathon_2-2/src/pretrained/bert_config.json \
--init_checkpoint=Gdrive/hackathon_2-2/src/pretrained/model_YJ_model.ckpt-200000 \
--do_train=True \
--train_file=Gdrive/hackathon_2-2/data/train/train.json \
--do_predict=True \
--predict_file=Gdrive/hackathon_2-2/data/dev/convert_dev.json \
--train_batch_size=12 \
--learning_rate=2e-5 \
--num_train_epochs=4.0 \
--max_seq_length=384 \
--doc_stride=128 \
--output_dir=Gdrive/hackathon_2-2/src/best_output \
--do_lower_case=False \
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python Gdrive/hackathon_2-2/src/manage_ans.py Gdrive/hackathon_2-2/data/dev/dev.json Gdrive/hackathon_2-2/src/best_output/predictions.json Gdrive/hackathon_2-2/result/dev_result.txt
# Out:
# origin input file path : Gdrive/hackathon_2-2/data/dev/dev.json
# origin prediction file path : Gdrive/hackathon_2-2/src/best_output/predictions.json
# convert prediction file path : Gdrive/hackathon_2-2/result/dev_result.txt

# %%
# !python Gdrive/hackathon_2-2/src/run_squad.py \
--vocab_file=Gdrive/hackathon_2-2/src/pretrained/vocab.txt \
--bert_config_file=Gdrive/hackathon_2-2/src/pretrained/bert_config.json \
--init_checkpoint=Gdrive/hackathon_2-2/src/pretrained/model_YJ_model.ckpt-200000 \
--do_train=False \
--train_file=Gdrive/hackathon_2-2/data/train/train.json \
--do_predict=True \
--predict_file=Gdrive/hackathon_2-2/data/test/convert_test.json \
--train_batch_size=12 \
--learning_rate=2e-5 \
--num_train_epochs=4.0 \
--max_seq_length=384 \
--doc_stride=128 \
--output_dir=Gdrive/hackathon_2-2/src/best_output \
--do_lower_case=False \
# Out:
# WARNING:tensorflow:From /content/Gdrive/hackathon_2-2/src/optimization.py:87: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From Gdrive/hackathon_2-2/src/run_squad.py:1283: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From Gdrive/hackathon_2-2/src/run_squad.py:1127: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0216 05:44:16.400381 140214410508160 module_wrapper.py:139] From Gdrive/hackathon_2-2/src/run_squad.py:1127: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From Gdrive/hackathon_2-2/src/run_squad.py:1127: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !python Gdrive/hackathon_2-2/src/manage_ans.py Gdrive/hackathon_2-2/data/test/test.json Gdrive/hackathon_2-2/src/best_output/predictions.json Gdrive/hackathon_2-2/result/test_result.txt
# Out:
# origin input file path : Gdrive/hackathon_2-2/data/test/test.json
# origin prediction file path : Gdrive/hackathon_2-2/src/best_output/predictions.json
# convert prediction file path : Gdrive/hackathon_2-2/result/test_result.txt
